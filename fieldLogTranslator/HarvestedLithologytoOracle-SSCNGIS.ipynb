# %% [markdown]
# # Reubens Work to Oracle

# %%
import sys
import os
import warnings
warnings.filterwarnings("ignore")
from collections import OrderedDict
import numpy as np
import pandas as pd

# %%
def loadHeader(log_path, print_missing_requireds = True):
    # Load the column name qualifiers
    header = pd.read_excel(log_path, sheet_name = 'Metadata', usecols= 'A:C')

    if print_missing_requireds:
        # Check all required fields are filled out
        for _, row in header.iterrows():
            if pd.isna(row['Value']) and row['Value Required'] == True:
                print('Compulsory field missing: populate ' + row['Attribute'] + ' for hole ' + str(header[header['Attribute'] == 'Hole Registration number']['Value'].values[0]) + ' before continuing')
    return header

# %%
def prepareDigitalLog(log_path):
    def createColumnNames(log_path):
        # Load the column name qualifiers/prefixes
        col_prefixes = pd.read_excel(log_path, sheet_name = 'Detailed Logging Form', skiprows = 0).columns

        # load the log columns
        log_cols = pd.read_excel(log_path, sheet_name = 'Detailed Logging Form', skiprows = 1).columns

        # combine the qualifier and colunm names to make better column names
        colname_lu = pd.Series(col_prefixes).apply(lambda x: x if x[0:8] != 'Unnamed:' else np.nan).fillna(method = 'ffill')
        new_cols = [colname_lu[i] + ': ' + col.strip() for i, col in enumerate(log_cols)]

        return new_cols
    
    # load the log data
    log = pd.read_excel(log_path, sheet_name = 'Detailed Logging Form', skiprows = 1)
    log.columns = createColumnNames(log_path)
    # remove the error in the template where a blank cell is populated with "  ferromagnesian"
    if log.loc[1, 'assemblage: maghaemite'] == '  ferromagnesian':
        log.loc[1, 'assemblage: maghaemite'] = np.nan    
    # if any of top, bottom and em1 lithology are null, drop
    log = log[log[['position: From (m bgl)','position: To (m bgl)', 'Extra Fields for Oracle: EM1 Lithology Name (eg, soil, muddy sand, sandstone), see lookup tab']].notna().all(axis = 1)]# 

    return log

# %%
def getENO(header):
    return header[header['Attribute'] == 'ENO']['Value'].values[0]

def getBoreholeName(header):
    return header[header['Attribute'] == 'Hole Registration number']['Value'].values[0]

def getCollectionName(header):
    return header[header['Attribute'] == 'Collection Name']['Value'].values[0]

def getSourceDocument(header):
    return header[header['Attribute'] == 'File Location']['Value'].values[0]

def getAccessGroup(header):
    return header[header['Attribute'] == 'Access Group']['Value'].values[0]

def getAccessCode(header):
    return header[header['Attribute'] == 'Access Code']['Value'].values[0]

def getConfidentialUntilDate(header):
    return header[header['Attribute'] == 'Confidential Until Date']['Value'].values[0]

def getQAStatus(header):
    return header[header['Attribute'] == 'QA Status']['Value'].values[0]

def getActivityCode(header):
    return header[header['Attribute'] == 'Activity Code']['Value'].values[0]

def getSampleID(header, row_num):
    return str(getBoreholeName(header)) + '.lithostrat.' + str(row_num + 1)

def getTemplateVersion(header):
    if 'Template Version' not in header.index:
        return 'old'
    else:
        return header['Template Version']

def getLithologyName(interval, column_name):
    lith = interval[column_name]
    if lith == '?':
        lith = 'unknown'
    elif pd.isna(lith):
        pass
    else:
        lith = lith.strip().lower()
    return lith
    

def useLithologyMaterialLU(em_lithology_name, column):
    if "material" in column.lower():
        column = 'MATERIAL CLASS'
    elif "group" in column.lower():
        column = 'LITHOLOGY GROUP'
    lu_path = r'\\prod.lan\active\proj\futurex\StuartCorridor\ScriptsTools\Consolidated_BH_Data\lithtype_lithgroup_materialclass_LU.xlsx'
    lu = pd.read_excel(lu_path, sheet_name='Mappings')
    lu = lu[lu.notna().all(axis = 1)]
    try:
        return lu[lu['LITHOLOGY TYPE'] == em_lithology_name][column].values[0]
    except:
        raise ValueError('{} is not filled out for {} in the lookup mapping file.\nPlease update the mapping file found at {}'.format(column, em_lithology_name, lu_path))
        return None

def makeBOREHOLEINTERVALCOLLECTION(header, template_path):
    s = 'Creating borehole header...'
    print(s, end = '', flush = True)
    
    # define each of the required fields for the bulk loader
    eno = getENO(header)
    borehole_name = getBoreholeName(header)
    depth_reference_point_id = header[header['Attribute'] == 'Depth Reference Point Id']['Value'].values[0]
    interval_collection_id =   ''  # will always be blank only required for existing holes
    collection_name = getCollectionName(header)
    collection_type = header[header['Attribute'] == 'Collection Type']['Value'].values[0]
    originator = 1328 # Mike Barnes' origno
    preferred_collection = header[header['Attribute'] == 'Preferred Collection']['Value'].values[0]
    collection_source_document = getSourceDocument(header)
    source_comments = header[header['Attribute'] == 'Source Comments']['Value'].values[0]

    # Put all the fields together in a list (in the correct order)
    bore_int_coll_entry = [eno, borehole_name, depth_reference_point_id, interval_collection_id, collection_name, collection_type, originator, preferred_collection, collection_source_document, source_comments]
    # Create a new entry at the bottom of the list with the list as data
    df_dict['BOREHOLE INTERVAL COLLECTION'].loc[len(df_dict['BOREHOLE INTERVAL COLLECTION'])] = bore_int_coll_entry
    print('Done')

# %%
def makeDOWNHOLEINTERVALSANDSAMPLES(header, row_num, interval):
    def makeComments(interval):
        if not pd.isna(interval['lithology: eg. Sand, fine; Clay; interbedded sand and silt and clay etc.']):
            c1 = interval['lithology: eg. Sand, fine; Clay; interbedded sand and silt and clay etc.']
        else:
            c1 = None
        if not pd.isna(interval['assemblage: Other Constituents (eg other minerals, organics, fossils etc)']):
            c2 = interval['assemblage: Other Constituents (eg other minerals, organics, fossils etc)']
        else:
            c2 = None
        if not pd.isna(interval['comments: Any additional observations']):
            c3 = interval['comments: Any additional observations']
        else:
            c3 = None

        comments = []
        for comment in [c1,c2,c3]:
            if comment is not None:
                if comments == []:
                    comments = comment
                else:
                    comments += ('. ' + comment)
        return comments  
    
    # Define the required fields
    eno = getENO(header)
    collection_no =  '' # not needed as are creating new rows in Oracle
    collection_name = getCollectionName(header)
    interval_id = '' # not needed as are creating new rows in Oracle
    intervalno = '' # not needed as are creating new rows in Oracle
    top = interval['position: From (m bgl)']
    bottom = interval['position: To (m bgl)']
    sampleno = '' # Oracle assigned primary key, always blank for new entries
    sampleid = getSampleID(header, row_num)
    logging_date = '3000-01-01' # header[header['Attribute'] == 'Logging Date']['Value'].values[0]
    parent_sampleno = '' # blank because these are new entries and the samples thus won't have a parent sample
    parent_sample_id = '' # as above
    access_group = getAccessGroup(header)
    access_code = getAccessCode(header)
    confidential_until_date = getConfidentialUntilDate(header)
    qa_status = getQAStatus(header)
    activity_code = getActivityCode(header)
    sample_type = 'borehole specimen' # header[header['Attribute'] == 'Sample Type']['Value'].values[0]
    sampling_method = 'drilling' # header[header['Attribute'] == 'Collection Name']['Value'].values[0]
    material_class = useLithologyMaterialLU(getLithologyName(interval, 'Extra Fields for Oracle: EM1 Lithology Name (eg, soil, muddy sand, sandstone), see lookup tab'), 'MATERIAL CLASS')
    sample_preparation = header[header['Attribute'] == 'Sample Preparation']['Value'].values[0]
    project = header[header['Attribute'] == 'Project']['Value'].values[0]
    specimen_storage_location = header[header['Attribute'] == 'Core Storage Location']['Value'].values[0]
    storage_date = header[header['Attribute'] == 'Storage Date']['Value'].values[0]
    comments = makeComments(interval)
    igsn = header[header['Attribute'] == 'IGSN']['Value'].values[0]
    specimen_mass = header[header['Attribute'] == 'Specimen Mass']['Value'].values[0]
    mass_uom = header[header['Attribute'] == 'Mass UOM']['Value'].values[0]
    source = getSourceDocument(header)

    # Add the fields, in order, in to a list
    downhole_int_samps_entry = [eno, collection_no, collection_name, interval_id, intervalno, top, bottom, sampleno, sampleid, logging_date, parent_sampleno, parent_sample_id, access_group, access_code, confidential_until_date, qa_status, activity_code, sample_type, sampling_method, material_class, sample_preparation, project,
                         specimen_storage_location, storage_date, comments, igsn, specimen_mass, mass_uom, source]
    # Add the fields as a new row in the relevant dataframe
    df_dict['DOWNHOLE INTERVALS AND SAMPLES'].loc[len(df_dict['DOWNHOLE INTERVALS AND SAMPLES'])] = downhole_int_samps_entry

# %%
def makeEARTHMATERIAL(interval, header, row_num):
    def makeAssemblageDescription(interval):
        # Proportion term lookup, transforming from the abbreviation on the logging sheet to the Oracle lookup constrained value
        assemblage_cols = [col for col in log.columns if col[0:10] == 'assemblage'][0:-3]
        s = ''
        for mineral, prop_term in interval[assemblage_cols].sort_values().iteritems():
            if not pd.isna(prop_term):
                if s == '':
                    s = proportion_term_lu[prop_term.strip()] + ' ' + mineral.split(':')[1].strip()
                else:
                    s += ', ' + proportion_term_lu[prop_term.strip()] + ' ' + mineral.split(':')[1].strip()
        if not pd.isna(interval['assemblage: Other Constituents (eg other minerals, organics, fossils etc)']):
            s += '. ' + interval['assemblage: Other Constituents (eg other minerals, organics, fossils etc)']
        return s
    
    def makeMineralQualifiers(interval):
        qualifier_lu = {'lithic fragments':'lithic'}
        qualifer_cols = [col for col in interval.index if col[0:10] == 'assemblage' and col.split(':')[1].strip() in qualifier_lu.keys()]
        qualifiers = interval[qualifer_cols].sort_values()
        qualifier_values = []
        for i, (mineral, prop_term) in enumerate(qualifiers.iteritems()):
            if not pd.isna(prop_term) and i < 3:
                mineral = mineral.split(':')[1].strip()
                qualifier_values.append(qualifier_lu[mineral])
        qualifier_values = qualifier_values + [''] * (3 - len(qualifier_values))
        return qualifier_values
    
    proportion_term_lu = {'D': 'dominant', 'M' : 'minor', 'T' : 'trace'}
    
    # #### EARTH MATERIALS  ####
    collection_name  = getCollectionName(header)
    sampleno = '' # not needed as it will be automatically generated from sampleid
    sampleid = getSampleID(header, row_num)
    access_code = getAccessCode(header)
    confidential_until_date = getConfidentialUntilDate(header)
    qa_status = getQAStatus(header)
    activity_code  = getActivityCode(header)
#     lithology_group defined in loop
#     lithology_name defined in loop
    qualifier_1, qualifier_2, qualifier_3 = makeMineralQualifiers(interval)
    material_description  = makeAssemblageDescription(interval)   # concatenation of assemblage descriptors
#     mode_of_occurence defined in loop
    proportion_term = ''  # numbers used instead
    # lower_proportion_percent defined in loop
    # upper_proportion_percent defined in loop
    if getTemplateVersion(header) != 'old':
        em_confidence = interval['Confidence: Lithology Type Confidence']
    else:
        em_confidence = ''
    # Extract the earth material details from the interval. There could be two earth materials
    em_fields = [col for col in interval.index if col.split(':')[1].strip()[0:2] == 'EM']
    # build a dict with the keys of the em number, with the value of a dict for lith name and lith proportion
    EMs = {emname : {'lith_type': None,'proportion': None} for emname in {em_field.split(':')[1].strip()[0:3] for em_field in em_fields}}
    # loop through the EM fields, and harvest the data and store it in the dict
    for em_field in em_fields:
        column_name = list(map(str.strip, em_field.split(':')[1].split(' '))) # EM1 or EM2
        if column_name[3] == 'Name':
            EMs[column_name[1]]['lith_type'] = getLithologyName(interval, em_field)
        if column_name[3] == '(%)':
            EMs[column_name[1]]['proportion'] = interval[em_field]

    for key, value in EMs.items():
        lithology_name = value['lith_type']
        if pd.isna(lithology_name):
            continue
        lithology_group = useLithologyMaterialLU(lithology_name, 'group')
        lower_proportion_percent = upper_proportion_percent = value['proportion']
        if lithology_group == 'organic':
            mode_of_occurence = ''
        else:
            mode_of_occurence = 'bed'
        
        earth_materials_entry = [collection_name, sampleno, sampleid, access_code, confidential_until_date, qa_status, activity_code, '', lithology_group, lithology_name,
                                 qualifier_1, qualifier_2, qualifier_3, material_description, mode_of_occurence, proportion_term, lower_proportion_percent,
                                 upper_proportion_percent, em_confidence]
        df_dict['EARTH MATERIALS'].loc[len(df_dict['EARTH MATERIALS'])] = earth_materials_entry

# %%
def makeEXTRAPROPERTIES(interval, header, row_num):
    def makeExtraProperty(geo_property, text_value = '', numerical_value = '', uom = '', proportion_term = '', prop_confidence = '', comment = ''):
        """
        Function for adding an extra property of an earth material to the relevant table.
        """
        extra_properties_entry = [sampleid, sampleno, datano, geo_property, text_value, numerical_value, uom, proportion_term, prop_confidence,
                                  comment, access_code, confidential_until_date, qa_status, activity_code, access_group] # for when proportion term is available
#         extra_properties_entry = [sampleid, sampleno, datano, geo_property, text_value, numerical_value, uom, prop_confidence, comment, access_code, confidential_until_date, qa_status, activity_code, access_group]
        df_dict['EXTRA PROPERTIES'].loc[len(df_dict['EXTRA PROPERTIES'])] = extra_properties_entry
        
    # functions for more complicated conversion from the log sheet to the Oracle lookup constrained format
    def makeGrainsizeProperties(interval):
        grainsize_lu = {'clay.1' :           ['clay (<0.002 mm)',''],
                        'silt':              ['silt (0.002-0.0625 mm)',''],
                        'very fine - fine':  ['fine sand (0.125-0.5mm)','very fine and fine classes combined during logging'],
                        'medium':            ['medium sand (0.25-0.5 mm)',''],
                        'coarse-very coarse':['coarse sand (0.5-1 mm)','coarse and very coarse classes combined during logging'],
                        'granule':           ['granule (2-4 mm)',''],
                        'pebble':            ['pebble (4-64 mm)',''],
                        'cobble':            ['cobble (64-256 mm)''']}
        grainsize_cols = [col for col in log.columns if col[0:10] == 'grain size']
        for col in grainsize_cols:
            if not pd.isna(interval[col]):
                makeExtraProperty('grainsize (Udden-Wentworth)', proportion_term = proportion_term_lu[interval[col]], text_value = grainsize_lu[col.split(':')[1].strip()][0], comment = grainsize_lu[col.split(':')[1].strip()][1], prop_confidence = prop_confidence)

    def makeRoundingProperties(interval):
        rounding_lu = {'VA':'very angular', 'A' :'angular', 'SA':'subangular', 'SR': 'subrounded', 'R':'rounded', 'WR':'well rounded'}
        rounding_heirachy = OrderedDict([('A',0), ('SA',1),('SR',2),('R',3), ('WR',4)])
        log_rounding = interval['round: Rounding']
        if pd.isna(log_rounding):
            return
        if '-' not in log_rounding:
            makeExtraProperty('rounding', proportion_term = 'all', text_value = rounding_lu[log_rounding], prop_confidence = prop_confidence)
        else:    
            round1, round2 = list(map(str.strip,log_rounding.split('-')))
            round1, round2 = rounding_heirachy[round1], rounding_heirachy[round2]
            start, end = min(round1, round2), max(round1, round2)
            for key in list(rounding_heirachy.keys())[start: end + 1]:
                makeExtraProperty('rounding', proportion_term = 'present', text_value = rounding_lu[key], prop_confidence = prop_confidence)

    def makeMineralProperties(interval):
        mineral_lu = {'quartz':'quartz',
                      'iron oxides':'iron oxide',
                      'maghaemite':'maghemite',
                      'calcite':'calcite',
                      'gypsum':'gypsum',
                      'mica' :'mica',
                      'feldspars':'feldspar',
                      'glauconite':'glauconite',
                      'sulphides':'sulphide'}
        assemblage_cols = [col for col in log.columns if col[0:10] == 'assemblage'][0:-3]
        for mineral, prop_term in interval[assemblage_cols].sort_values().iteritems():
            if not pd.isna(prop_term):
                mineral = mineral.split(':')[1].strip()
                if mineral in mineral_lu.keys():
                    makeExtraProperty('mineral', proportion_term = proportion_term_lu[prop_term], text_value = mineral_lu[mineral], prop_confidence = prop_confidence)
    
    def makeColourProperties(interval):
        # define the columns related to Munsell Colours
        colour_cols = [col for col in log.columns if col[0:7] == 'colour:'][0:3]
        
        # create flag for if colours are grading or not
        gradingColour = True if interval['Colour: Does the colour grade from Dominant to Minor (Y/N)'] == 'Y' else False
            
        # if the colours are described as grading, make the comment string    
        if gradingColour:
            s = ''
            for col in colour_cols:
                if not pd.isna(interval[col]):
                    if s == '':
                        s = 'colour grading from ' + interval[col] + ' at top'
                    else:
                        s = s + ' to ' + interval[col]
        # loop through colours and add to Extra properties, with with proportion term and no grading desciption or with grading desc but no propotion
        for i, col in enumerate(colour_cols):
            if not pd.isna(interval[col]):
                if gradingColour:
                    proportion = ''
                    comment = s
                else:
                    if i == 0:
                        proportion = 'dominant'
                    else:
                        proportion = 'minor'
                    comment = ''
                makeExtraProperty('colour', proportion_term = proportion, text_value = interval[col], comment = comment, prop_confidence = prop_confidence)
      
        
    # Proportion term lookup, transforming from the abbreviation on the logging sheet to the Oracle lookup constrained value
    proportion_term_lu = {'D': 'dominant',
                          'M' : 'minor',
                          'T' : 'trace'}
    # #### EXTRA PROPERTIES INPUTS ####
    sampleid  = getSampleID(header, row_num)
    sampleno = ''  #not required
    datano = '' # this will always be blank as is only used for updating existing entires
    # proportion_term to be defined in function call
#     geo_propertyto be defined in function call 
#     text_value to be defined in function call
#     numerical_value  to be defined in function call
#     text_value to be defined in function call
#     uom to be defined in function call
    if getTemplateVersion(header) != 'old':
        prop_confidence = interval['Confidence: Extra Properties Confidence']
    else:
        prop_confidence = ''
#     comment to be defined in function call
    access_code = getAccessCode(header)    
    confidential_until_date = getConfidentialUntilDate(header)    
    qa_status = getQAStatus(header)    
    activity_code = getActivityCode(header)    
    access_group = getAccessGroup(header)

    # colours
    makeColourProperties(interval)
    
    # patterns
    colour_pattern_lu = {'M': 'uniform',
                 'BD' : 'striped',
                 'SK' : 'striped',
                 'BL' : 'mottled',
                 'MT' : 'mottled',
                 'SP' : 'mottled'}
    if not pd.isna(interval['Colour: pattern']):
        makeExtraProperty('colour pattern', text_value = colour_pattern_lu[interval['Colour: pattern']], prop_confidence = prop_confidence)

    # minerals
    makeMineralProperties(interval)
        
    # grainsize
    makeGrainsizeProperties(interval)

    # sorting
    if not pd.isna(interval['sort: Sorting']):
        sorting_lu = {'P': 'poorly sorted',
              'M' : 'moderately sorted',
              'W' : 'well sorted'}
        makeExtraProperty('sorting', text_value = sorting_lu[interval['sort: Sorting']], prop_confidence = prop_confidence)

    # rounding
    makeRoundingProperties(interval)

    # bedding
    if not pd.isna(interval['bed: Bedding']):
        bedding_lu = {'VTL' : 'laminated (<10 mm)',
              'L' : 'laminated (<10 mm)',
              'VTB' : 'very thin (10-30 mm)',
              'TB' : 'thin (30-100 mm)',
              'MB' : 'medium (100-300 mm)',
              'FB' : 'thick (300-1000 mm)',
              'VFB' : 'very thick (>1000 mm)'}
        makeExtraProperty('bedding thickness', text_value = bedding_lu[interval['bed: Bedding']], prop_confidence = prop_confidence)

    # sedimentary structures
    if not pd.isna(interval['structures: Sedimentary Features']):
        sed_strucs = list(map(str.strip,interval['structures: Sedimentary Features'].split(',')))
        for struc in sed_strucs:
            if pd.isna(struc):
                continue
            else:
                makeExtraProperty('sedimentary features', text_value = struc)
    
    # boundary
    if not pd.isna(interval['boundary: Lower boundary type']):
        makeExtraProperty('base contact character', text_value = interval['boundary: Lower boundary type'], prop_confidence = prop_confidence)

    # weathering
    if not pd.isna(interval['wth: Weathering']):
        weathering_lu = {'R' : 'completely weathered',
                         'X' : 'very highly weathered',
                         'D' : 'moderately weathered',
                         'S' : 'slightly weathered',
                         'F' : 'fresh'}
        makeExtraProperty('weathering degree', text_value = weathering_lu[interval['wth: Weathering']], prop_confidence = prop_confidence)    
    
    # induration
    if not pd.isna(interval['ind: ferrugenous']):
        ferrugenous_lu = {'N' : ['induration style','ferruginous nodules', ''],
                          'P' : ['sedimentary features','pisolites', 'ferrugenous'],
                          'L' : ['induration style', 'ferruginous induration', ''],
                          'C' : ['induration style', 'ferruginous induration', '']}
        makeExtraProperty(ferrugenous_lu[interval['ind: ferrugenous']][0], text_value = ferrugenous_lu[interval['ind: ferrugenous']][1], comment = ferrugenous_lu[interval['ind: ferrugenous']][2], prop_confidence = prop_confidence)

    if not pd.isna(interval['ind: calcareous']):
        calcareous_lu = {'N' : ['induration style','calcareous nodules', ''],
                  'P' : ['sedimentary features','pisolites', 'calcareous'],
                  'L' : ['induration style', 'calcareous induration', ''],
                  'C' : ['induration style', 'calcareous induration', '']}
        makeExtraProperty(calcareous_lu[interval['ind: calcareous']][0], text_value = calcareous_lu[interval['ind: calcareous']][1], comment = calcareous_lu[interval['ind: calcareous']][2], prop_confidence = prop_confidence)

    if not pd.isna(interval['ind: siliceous']):
        siliceous_lu = {'N' : ['induration style','siliceous nodules', ''],
                  'P' : ['sedimentary features','pisolites', 'siliceous'],
                  'L' : ['induration style', 'siliceous induration', ''],
                  'C' : ['induration style', 'siliceous induration', '']}
        makeExtraProperty(siliceous_lu[interval['ind: siliceous']][0], text_value = siliceous_lu[interval['ind: siliceous']][1], comment = siliceous_lu[interval['ind: siliceous']][2], prop_confidence = prop_confidence)

    # moisture
    if not pd.isna(interval['wet: Moisture']):
        moisture_lu = {'W' : 'wet',
                       'M' : 'moist',
                       'D' : 'dry'}
        makeExtraProperty('moisture', text_value = moisture_lu[interval['wet: Moisture']], prop_confidence = prop_confidence)

# %%
def captureSTRATIGRAPHY(interval, header, row_num):
    collection_name = 'Bore Report Stratigraphy'
    sampleno = '' # Oracle assigned primary key, always blank for new entries
    sampleid = getSampleID(header, row_num)
    access_code = getAccessCode(header)    
    confidential_until_date = getConfidentialUntilDate(header)    
    qa_status = getQAStatus(header)
    activity_code = getActivityCode(header)    
    formal_unit_name = ''
    informal_unit_name = interval['Strat: Stratigraphy']
    ga_preferred = 'Y'
    informal_grouping = ''
    geological_province = ''
    min_numeric_age = ''
    min_age_name = ''
    max_numeric_age = ''
    max_age_name = ''
    age_method = ''
    top_contact_type = ''
    top_contact_character = ''
    top_contact_name = ''
    base_contact_type = ''
    base_contact_character = ''
    base_contact_name = ''
    remarks = ''
    confidence = ''
    
    # Add the fields, in order, in to a list
    strat_entry = [collection_name, sampleno, sampleid, access_code, confidential_until_date, qa_status, activity_code, '', formal_unit_name, informal_unit_name,
    ga_preferred, informal_grouping, geological_province, min_numeric_age, min_age_name, max_numeric_age, max_age_name, age_method, top_contact_type,
    top_contact_character, top_contact_name, base_contact_type, base_contact_character, base_contact_name, remarks, confidence]
    
    # Add the fields as a new row in the relevant dataframe
    df_dict['STRATIGRAPHY'].loc[len(df_dict['STRATIGRAPHY'])] = strat_entry

# %%
def processEntireHole(log_path):
        # load log header data
    s = 'Loading header details...'
    print(s, end = '', flush = True)
    header = loadHeader(log_path)
    hole = getBoreholeName(header)
    print('Done')
    print('Starting Oracle bulk loader processing for', log_path)

    # load and reformat log sheet transcription
    s = 'Loading log sheet...'
    print(s, end = '', flush = True)
    log = prepareDigitalLog(log_path)
    print('Done')
    
    if len(log) == 0:
        print('No valid lithology log entries for {}'.format(hole))
        print('-----------------------------------')
        return

    # make the borehole interval collection row (1 row per hole)
    makeBOREHOLEINTERVALCOLLECTION(header, template_path)
    s = 'Creating downhole intervals and samples, earth materials and extra properties...'
    print(s, end = '', flush = True)
    for row_num, interval in log.iterrows():
        # make the samples rows (1 row per described interval)
        makeDOWNHOLEINTERVALSANDSAMPLES(header, row_num, interval)

        # make the earth materials row (up to 2 per sample)
        makeEARTHMATERIAL(interval, header, row_num)

        # make the extra property rows (potentially 10 or more per earth material)
        makeEXTRAPROPERTIES(interval, header, row_num)
        
        if pd.notna(interval['Strat: Stratigraphy']):
            captureSTRATIGRAPHY(interval, header, row_num)

    print('Done')
    print(hole, 'is processed and ready for loading into Oracle')
    print('-----------------------------------')

# %%
# define the template location
template_path = r"\\prod.lan\active\proj\futurex\Common\Working\Mike\GitHub\mjb_work_code\DataMan_Tools\Borehole-Samples-downhole intervals-geological observations bulk_loading_template_2019.01.xlsx"

# load the destination worksheets from the bulk loader (as dataframes to store results into)
s = 'Creating destination dataframes...'
print(s, end = '', flush = True)
df_dict = {sheet : pd.read_excel(template_path, sheet_name = sheet, skiprows = 4) for sheet in ['BOREHOLE INTERVAL COLLECTION', 'DOWNHOLE INTERVALS AND SAMPLES',
                                                                                                'EARTH MATERIALS', 'STRATIGRAPHY','EXTRA PROPERTIES']}
# remove the dummy data in the bulk loader
df_dict = {key : value.drop(value.index) for key, value in df_dict.items()}

print('Done')
print('-----------------------------------')
# Out:
# Creating destination dataframes...Done
# -----------------------------------

# %% [markdown]
# ## Build List of spreadsheets to Import

# %%
first_root_dir = r'\\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\'

processed = pd.DataFrame(columns = ['bore_name','file_path','hasLithology','hasStratigraphy'])


for cur_dir, sub_dirs, files in os.walk(first_root_dir):
    for file in files:
        if file.startswith('RN0') and file.endswith('.xlsx'):
            bore_name = file.split('_')[0]
            file_path = os.path.join(cur_dir, file)
            df = pd.read_excel(file_path, sheet_name = 'Detailed Logging Form', skiprows = 1)
            hasLithology = True if ((df['From (m bgl)'].notna().sum() >0) and (df['EM1 Lithology Name (eg, soil, muddy sand, sandstone), see lookup tab'].notna().sum()  > 0)) else False
            hasStratigraphy = True if df['Stratigraphy'].notna().sum() > 0 else False
            processed.loc[len(processed)] = [bore_name, file_path, hasLithology, hasStratigraphy]
# Drop Reubens master files that have been imported as part of this process
processed = processed[processed['bore_name'] != 'RN0']
processed = processed[processed['bore_name'].notna()].reset_index(drop = True)
print('{} holes have been checked'.format(len(processed)))
processed = processed[processed['hasLithology'] | processed['hasStratigraphy']]
print('{} holes have some useful data'.format(len(processed)))
processed['error'] = ''
processed.head()
# Out:
# 578 holes have been checked
# 455 holes have some useful data
#   bore_name                                          file_path hasLithology  \
# 0  RN029653  \\prod.lan\active\proj\futurex\StuartCorridor\...         True
# 1  RN029656  \\prod.lan\active\proj\futurex\StuartCorridor\...         True
# 2  RN029660  \\prod.lan\active\proj\futurex\StuartCorridor\...         True
# 3  RN029662  \\prod.lan\active\proj\futurex\StuartCorridor\...         True
# 4  RN029663  \\prod.lan\active\proj\futurex\StuartCorridor\...         True
#
#   hasStratigraphy error
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %%
processed[processed.duplicated('bore_name', keep = False)].sort_values('bore_name')

# %%
for i, row in processed.iterrows():
#     if hole_name == 'RN010703':
#         processEntireHole(path) 
#     if i < 100:
#     if row['bore_name'] == 'RN015136':
    try:
        processEntireHole(row['file_path'])
        processed.loc[i, 'error'] = 'No'
    except Exception as e:
        processed.loc[i, 'error'] = str(e)
#     else:
#         continue

df_dict['BOREHOLE INTERVAL COLLECTION']['COLLECTION SOURCE DOCUMENT ID'] = np.nan #df_dict['BOREHOLE INTERVAL COLLECTION']['COLLECTION SOURCE DOCUMENT ID'].str.replace('T:','\\\\prod.lan\\active')
df_dict['DOWNHOLE INTERVALS AND SAMPLES']['SOURCE'] = df_dict['DOWNHOLE INTERVALS AND SAMPLES']['SOURCE'].str.replace('T:','\\\\prod.lan\\active')
# Out:
# Loading header details...Compulsory field missing: populate ENO for hole RN029653 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN029653 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN029653_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN029653 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN029656 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN029656 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN029656_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Loading header details...Compulsory field missing: populate ENO for hole RN029660 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN029660 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN029660_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN029660 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN029662 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN029662 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN029662_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN029662 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN029663 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN029663 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN029663_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN029663 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN029665 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN029665 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN029665_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN029665 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN029666 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN029666 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN029666_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN029666 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN030826 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN030826 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN030826_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN030826 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN034821 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN034821 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN034821_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN034821 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN038543 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN038543 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN038543_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN038543 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN007412 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN007412 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\RN007412_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN007412 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN034821 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN034821 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\East Kimberley\Completed borehole logs for Viktoria\RN034821_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN034821 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013453 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013453 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN013453_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013453 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013454 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013454 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN013454_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013454 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013455 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013455 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN013455_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013455 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013457 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013457 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN013457_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013457 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013458 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013458 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN013458_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013458 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN016933 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN016933 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN016933_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN016933 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN017585 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017585 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017585_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017585 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate GWB Hole Name for hole RN017587 before continuing
# Compulsory field missing: populate ENO for hole RN017587 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017587 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017587_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017587 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate GWB Hole Name for hole RN017589 before continuing
# Compulsory field missing: populate ENO for hole RN017589 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017589 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017589_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017589 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate GWB Hole Name for hole RN017591 before continuing
# Compulsory field missing: populate ENO for hole RN017591 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017591 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017591_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017591 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate GWB Hole Name for hole RN017594 before continuing
# Compulsory field missing: populate ENO for hole RN017594 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017594 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017594_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017594 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018114 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018114 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018114_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018114 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018402 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018402 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018402_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Loading header details...Compulsory field missing: populate ENO for hole RN019114 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN019114 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN019114_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN019114 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN019115 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN019115 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN019115_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN019115 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN019136 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN019136 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN019136_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN019136 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN017350 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017350 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017350_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017350 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018133 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018133 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018133_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018133 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018603 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018603 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018603_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018603 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018612 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018612 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018612_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Loading header details...Compulsory field missing: populate ENO for hole RN018892 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018892 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018892_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018892 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018912 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018912 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018912_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Loading header details...Compulsory field missing: populate ENO for hole RN018921 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018921 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018921_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018921 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018925 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018925 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018925_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018925 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN006504 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN006504 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN006504_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN006504 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN010285 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN010285 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN010285_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN010285 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN017339 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017339 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017339_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017339 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN017393 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017393 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017393_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017393 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN017536 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017536 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017536_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017536 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN017537 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN017537 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN017537_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN017537 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018334 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018334 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018334_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018334 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013214 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013214 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN013214_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013214 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN015877 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN015877 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN015877_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN015877 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN018144 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN018144 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Induction + Gamma logs with stratigraphy\Southern Stuart Corridor\RN018144_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN018144 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN000444 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN000444 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN000444_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN000444 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013523 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013523 before continuing
# Compulsory field missing: populate Logged By for hole RN013523 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN013523_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013523 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013745 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013745 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN013745_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013745 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002402 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002402 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN002402_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002402 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002401 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002401 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN002401_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002401 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002168 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002168 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN002168_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002168 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013746 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013746 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN013746_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013746 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013747 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013747 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN013747_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013747 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013205 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013205 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN013205_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013205 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN000651 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN000651 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Ti-Tree\RN000651_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN000651 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013210 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013210 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN013210_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013210 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN003379 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN003379 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN003379_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN003379 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN010955 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN010955 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN010955_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN010955 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN012905 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN012905 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN012905_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN012905 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013211 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013211 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN013211_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013211 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013215 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013215 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN013215_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013215 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013217 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013217 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN013217_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013217 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013221 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013221 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN013221_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013221 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013209 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013209 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Laramba\RN013209_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013209 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013002 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013002 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN013002_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013002 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013995 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013995 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN013995_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013995 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN000576 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN000576 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN000576_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN000576 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN012845 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN012845 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN012845_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN012845 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN001868 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN001868 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN001868_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN001868 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002994 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002994 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN002994_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002994 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN011345 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN011345 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN011345_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN011345 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN011348 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN011348 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN011348_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN011348 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN013489 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN013489 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN013489_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN013489 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN015243 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN015243 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN015243_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN015243 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN015257 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN015257 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed Second priority\Harts Range Engawala\RN015257_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# ...
# Compulsory field missing: populate Depth Reference Point Id for hole RN005385 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005385_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005385 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN005365 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN005365 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005365_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005365 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN005356 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN005356 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005356_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005356 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN010931 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN010931 before continuing
# Compulsory field missing: populate Sample Method for hole RN010931 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN010931_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Loading header details...Compulsory field missing: populate ENO for hole RN010927 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN010927 before continuing
# Compulsory field missing: populate Logging Date for hole RN010927 before continuing
# Compulsory field missing: populate Sample Method for hole RN010927 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN010927_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Loading header details...Compulsory field missing: populate ENO for hole RN005355 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN005355 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005355_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005355 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN005349 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN005349 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005349_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005349 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN005340 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN005340 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005340_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005340 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN005335 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN005335 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005335_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005335 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN005257 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN005257 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN005257_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN005257 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN004835 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN004835 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN004835_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN004835 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN004382 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN004382 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN004382_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Loading header details...Compulsory field missing: populate ENO for hole RN004225 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN004225 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN004225_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN004225 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN003777 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN003777 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN003777_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN003777 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN003511 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN003511 before continuing
# Compulsory field missing: populate Sample Type for hole RN003511 before continuing
# Compulsory field missing: populate Sample Method for hole RN003511 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN003511_SSC.xlsx
# Loading log sheet...Done
# No valid lithology log entries for RN003511
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN003214 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN003214 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN003214_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN003214 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN003183 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN003183 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN003183_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN003183 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002807 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002807 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN002807_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002807 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN011569 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN011569 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN011569_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN011569 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002715 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002715 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN002715_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002715 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002402 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002402 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN002402_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002402 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002401 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002401 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN002401_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002401 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN002168 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN002168 before continuing
# Compulsory field missing: populate Sample Type for hole RN002168 before continuing
# Compulsory field missing: populate Sample Method for hole RN002168 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN002168_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN002168 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN001604 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN001604 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN001604_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN001604 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN000628 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN000628 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN000628_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN000628 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN000444 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN000444 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN000444_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN000444 is processed and ready for loading into Oracle
# -----------------------------------
# Loading header details...Compulsory field missing: populate ENO for hole RN015136 before continuing
# Compulsory field missing: populate Depth Reference Point Id for hole RN015136 before continuing
# Done
# Starting Oracle bulk loader processing for \\prod.lan\active\proj\futurex\StuartCorridor\Working\Reuben\Boreholes_stratlith\\Completed\RN015136_SSC.xlsx
# Loading log sheet...Done
# Creating borehole header...Done
# Creating downhole intervals and samples, earth materials and extra properties...Done
# RN015136 is processed and ready for loading into Oracle
# -----------------------------------

# %%
processed.loc[577,'file_path'] #.tail()
# processed['error'].unique()
# Out:
# '\\\\prod.lan\\active\\proj\\futurex\\StuartCorridor\\Working\\Reuben\\Boreholes_stratlith\\\\Completed\\RN015136_SSC.xlsx'

# %%
df = prepareDigitalLog(processed.loc[577,'file_path'])
df
# Out:
#    position: From (m bgl)  position: To (m bgl)  \
# 0                     0.0                   5.0
# 1                     5.0                  21.0
# 2                    21.0                  90.0
#
#   lithology: eg. Sand, fine; Clay; interbedded sand and silt and clay etc.  \
# 0                                         Sandy Clay
# 1                                 Limestone and Clay
# 2                                            Granite
#
#    Colour: dominant  Colour: minor 1  Colour: minor 2  Colour: pattern  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN
#
#    Colour: Does the colour grade from Dominant to Minor (Y/N)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    grainsize %: clay  grainsize %: silt  ...  assemblage: Unnamed: 48  \
# 0                NaN                NaN  ...                      NaN
# 1                NaN                NaN  ...                      NaN
# 2                NaN                NaN  ...                      NaN
#
#    assemblage: Unnamed: 49  comments: Any additional observations  \
# 0                      NaN                                    NaN
# 1                      NaN                                    NaN
# 2                      NaN  Water Struck at 42.63 m       2 L/sec
#
#    Extra Fields for Oracle: Sample Type (ie core or cuttings). See lookup tab  \
# 0                               drill chips/cuttings
# 1                               drill chips/cuttings
# 2                               drill chips/cuttings
#
#    Extra Fields for Oracle: EM1 Lithology Name (eg, soil, muddy sand, sandstone), see lookup tab  \
# 0                                         sandy clay
# 1                                          limestone
# 2                                            granite
#
#    Extra Fields for Oracle: EM1 Proportion (%)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#    Extra Fields for Oracle: EM2 Lithology Name (eg, soil, muddy sand, sandstone)  \
# 0                                                NaN
# 1                                               clay
# 2                                                NaN
#
#    Extra Fields for Oracle: EM2 Proportion (%)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#    LogType: Lith Log Type ("driller", "geologist", "unknown")  \
# 0                                            Driller
# 1                                            Driller
# 2                                            Driller
#
#    Strat: Stratigraphy
# 0                  NaN
# 1                  NaN
# 2                  NaN
#
# [3 rows x 58 columns]

# %%
df_dict['BOREHOLE INTERVAL COLLECTION'].head()
# Out:
#    BOREHOLE ENO BOREHOLE NAME  DEPTH REFERENCE POINT ID  \
# 0           NaN      RN029653                       NaN
# 1           NaN      RN029656                       NaN
# 2           NaN      RN029660                       NaN
# 3           NaN      RN029662                       NaN
# 4           NaN      RN029663                       NaN
#
#   INTERVAL COLLECTION ID      COLLECTION NAME COLLECTION TYPE  \
# 0                         GA Lithological Log    lithological
# 1                         GA Lithological Log    lithological
# 2                         GA Lithological Log    lithological
# 3                         GA Lithological Log    lithological
# 4                         GA Lithological Log    lithological
#
#    ORIGINATOR NUMBER PREFERRED COLLECTION  \
# 0               1328                    Y
# 1               1328                    Y
# 2               1328                    Y
# 3               1328                    Y
# 4               1328                    Y
#
#                        COLLECTION SOURCE DOCUMENT ID  SOURCE COMMENTS
# 0  \\prod.lan\active\proj\futurex\StuartCorridor\...              NaN
# 1  \\prod.lan\active\proj\futurex\StuartCorridor\...              NaN
# 2  T:\proj\futurex\StuartCorridor\Working\Reuben\...              NaN
# 3  T:\proj\futurex\StuartCorridor\Working\Reuben\...              NaN
# 4  T:\proj\futurex\StuartCorridor\Working\Reuben\...              NaN

# %%
df_dict['DOWNHOLE INTERVALS AND SAMPLES']#[df_dict['DOWNHOLE INTERVALS AND SAMPLES'].columns[20:]].head()
# Out:
#     BOREHOLE ENO COLLECTION NO.      COLLECTION NAME INTERVAL ID INTERVALNO  \
# 0            NaN                 GA Lithological Log
# 1            NaN                 GA Lithological Log
# 2            NaN                 GA Lithological Log
# 3            NaN                 GA Lithological Log
# 4            NaN                 GA Lithological Log
# 5            NaN                 GA Lithological Log
# 6            NaN                 GA Lithological Log
# 7            NaN                 GA Lithological Log
# 8            NaN                 GA Lithological Log
# 9            NaN                 GA Lithological Log
# 10           NaN                 GA Lithological Log
# 11           NaN                 GA Lithological Log
# 12           NaN                 GA Lithological Log
# 13           NaN                 GA Lithological Log
# 14           NaN                 GA Lithological Log
# 15           NaN                 GA Lithological Log
# 16           NaN                 GA Lithological Log
# 17           NaN                 GA Lithological Log
# 18           NaN                 GA Lithological Log
# 19           NaN                 GA Lithological Log
# 20           NaN                 GA Lithological Log
# 21           NaN                 GA Lithological Log
# 22           NaN                 GA Lithological Log
# 23           NaN                 GA Lithological Log
# 24           NaN                 GA Lithological Log
# 25           NaN                 GA Lithological Log
# 26           NaN                 GA Lithological Log
# 27           NaN                 GA Lithological Log
# 28           NaN                 GA Lithological Log
# 29           NaN                 GA Lithological Log
# 30           NaN                 GA Lithological Log
# 31           NaN                 GA Lithological Log
# 32           NaN                 GA Lithological Log
# 33           NaN                 GA Lithological Log
# 34           NaN                 GA Lithological Log
# 35           NaN                 GA Lithological Log
# 36           NaN                 GA Lithological Log
# 37           NaN                 GA Lithological Log
# 38           NaN                 GA Lithological Log
# 39           NaN                 GA Lithological Log
# 40           NaN                 GA Lithological Log
# 41           NaN                 GA Lithological Log
# 42           NaN                 GA Lithological Log
# 43           NaN                 GA Lithological Log
# 44           NaN                 GA Lithological Log
# 45           NaN                 GA Lithological Log
# 46           NaN                 GA Lithological Log
# 47           NaN                 GA Lithological Log
# 48           NaN                 GA Lithological Log
# 49           NaN                 GA Lithological Log
#
#     INTERVAL START DEPTH  INTERVAL END DEPTH SAMPLENO              SAMPLE ID  \
# 0                    0.0                1.30           RN029653.lithostrat.1
# 1                    1.3                3.50           RN029653.lithostrat.2
# 2                    3.5                6.90           RN029653.lithostrat.3
# 3                    6.9                7.50           RN029653.lithostrat.4
# 4                    7.5               18.00           RN029653.lithostrat.5
# 5                   18.0               18.80           RN029653.lithostrat.6
# 6                    0.0                1.70           RN029656.lithostrat.1
# 7                    1.7                6.90           RN029656.lithostrat.2
# 8                    6.9               18.00           RN029656.lithostrat.3
# 9                   18.0               22.00           RN029656.lithostrat.4
# 10                  22.0               29.30           RN029656.lithostrat.5
# 11                  29.3               30.80           RN029656.lithostrat.6
# 12                  30.8               35.50           RN029656.lithostrat.7
# 13                   0.0                1.70           RN029660.lithostrat.1
# 14                   1.7                6.50           RN029660.lithostrat.2
# 15                   6.5               29.70           RN029660.lithostrat.3
# 16                   0.0                1.70           RN029662.lithostrat.1
# 17                   1.7                5.00           RN029662.lithostrat.2
# 18                   5.0               10.70           RN029662.lithostrat.3
# 19                  10.7               20.20           RN029662.lithostrat.4
# 20                  20.2               21.20           RN029662.lithostrat.5
# 21                   0.0                1.70           RN029663.lithostrat.1
# 22                   1.7               10.00           RN029663.lithostrat.2
# 23                  10.0               11.70           RN029663.lithostrat.3
# 24                  11.7               21.50           RN029663.lithostrat.4
# 25                  21.5               21.70           RN029663.lithostrat.5
# 26                   0.0                1.70           RN029665.lithostrat.1
# 27                   1.7                6.90           RN029665.lithostrat.2
# 28                   6.9               17.70           RN029665.lithostrat.3
# 29                  17.7               18.40           RN029665.lithostrat.4
# 30                  18.4               24.60           RN029665.lithostrat.5
# 31                   0.0                1.70           RN029666.lithostrat.1
# 32                   1.7                6.00           RN029666.lithostrat.2
# 33                   6.0               17.70           RN029666.lithostrat.3
# 34                   0.0                1.00           RN030826.lithostrat.1
# 35                   1.0                6.00           RN030826.lithostrat.2
# 36                   6.0                8.00           RN030826.lithostrat.3
# 37                   8.0               11.00           RN030826.lithostrat.4
# 38                  11.0               31.00           RN030826.lithostrat.5
# 39                  31.0               32.00           RN030826.lithostrat.6
# 40                   0.0                0.50           RN034821.lithostrat.1
# 41                   0.5                3.40           RN034821.lithostrat.2
# 42                   3.4                4.20           RN034821.lithostrat.3
# 43                   4.2                5.70           RN034821.lithostrat.4
# 44                   5.7                5.80           RN034821.lithostrat.5
# 45                   5.8               10.50           RN034821.lithostrat.6
# 46                  10.5               11.85           RN034821.lithostrat.7
# 47                   0.0                1.50           RN038543.lithostrat.1
# 48                   1.5                8.00           RN038543.lithostrat.2
# 49                   8.0               24.00           RN038543.lithostrat.3
#
#    ACQUISITION DATE  ... MATERIAL CLASS PROCEDURE NO.  \
# 0        3000-01-01  ...       regolith           NaN
# 1        3000-01-01  ...       sediment           NaN
# 2        3000-01-01  ...       sediment           NaN
# 3        3000-01-01  ...       sediment           NaN
# 4        3000-01-01  ...       sediment           NaN
# 5        3000-01-01  ...           rock           NaN
# 6        3000-01-01  ...       regolith           NaN
# 7        3000-01-01  ...       sediment           NaN
# 8        3000-01-01  ...       sediment           NaN
# 9        3000-01-01  ...       sediment           NaN
# 10       3000-01-01  ...           rock           NaN
# 11       3000-01-01  ...           rock           NaN
# 12       3000-01-01  ...           rock           NaN
# 13       3000-01-01  ...       regolith           NaN
# 14       3000-01-01  ...       sediment           NaN
# 15       3000-01-01  ...       sediment           NaN
# 16       3000-01-01  ...       regolith           NaN
# 17       3000-01-01  ...       sediment           NaN
# 18       3000-01-01  ...       sediment           NaN
# 19       3000-01-01  ...       sediment           NaN
# 20       3000-01-01  ...           rock           NaN
# 21       3000-01-01  ...       regolith           NaN
# 22       3000-01-01  ...       sediment           NaN
# 23       3000-01-01  ...       sediment           NaN
# 24       3000-01-01  ...       sediment           NaN
# 25       3000-01-01  ...           rock           NaN
# 26       3000-01-01  ...       regolith           NaN
# 27       3000-01-01  ...       sediment           NaN
# 28       3000-01-01  ...       sediment           NaN
# 29       3000-01-01  ...       sediment           NaN
# 30       3000-01-01  ...       sediment           NaN
# 31       3000-01-01  ...       regolith           NaN
# 32       3000-01-01  ...       sediment           NaN
# 33       3000-01-01  ...       sediment           NaN
# 34       3000-01-01  ...       sediment           NaN
# 35       3000-01-01  ...       sediment           NaN
# 36       3000-01-01  ...       sediment           NaN
# 37       3000-01-01  ...       sediment           NaN
# 38       3000-01-01  ...           rock           NaN
# 39       3000-01-01  ...           rock           NaN
# 40       3000-01-01  ...       sediment           NaN
# 41       3000-01-01  ...       sediment           NaN
# 42       3000-01-01  ...       sediment           NaN
# 43       3000-01-01  ...       sediment           NaN
# 44       3000-01-01  ...           rock           NaN
# 45       3000-01-01  ...           rock           NaN
# 46       3000-01-01  ...           rock           NaN
# 47       3000-01-01  ...       sediment           NaN
# 48       3000-01-01  ...       sediment           NaN
# 49       3000-01-01  ...           rock           NaN
#
#                          PROJECT SPECIMEN STORAGE LOCATION  STORAGE DATE  \
# 0   EFTF - South Stuart Corridor                       NaN           NaN
# 1   EFTF - South Stuart Corridor                       NaN           NaN
# 2   EFTF - South Stuart Corridor                       NaN           NaN
# 3   EFTF - South Stuart Corridor                       NaN           NaN
# 4   EFTF - South Stuart Corridor                       NaN           NaN
# 5   EFTF - South Stuart Corridor                       NaN           NaN
# 6   EFTF - South Stuart Corridor                       NaN           NaN
# 7   EFTF - South Stuart Corridor                       NaN           NaN
# 8   EFTF - South Stuart Corridor                       NaN           NaN
# 9   EFTF - South Stuart Corridor                       NaN           NaN
# 10  EFTF - South Stuart Corridor                       NaN           NaN
# 11  EFTF - South Stuart Corridor                       NaN           NaN
# 12  EFTF - South Stuart Corridor                       NaN           NaN
# 13  EFTF - South Stuart Corridor                       NaN           NaN
# 14  EFTF - South Stuart Corridor                       NaN           NaN
# 15  EFTF - South Stuart Corridor                       NaN           NaN
# 16  EFTF - South Stuart Corridor                       NaN           NaN
# 17  EFTF - South Stuart Corridor                       NaN           NaN
# 18  EFTF - South Stuart Corridor                       NaN           NaN
# 19  EFTF - South Stuart Corridor                       NaN           NaN
# 20  EFTF - South Stuart Corridor                       NaN           NaN
# 21  EFTF - South Stuart Corridor                       NaN           NaN
# 22  EFTF - South Stuart Corridor                       NaN           NaN
# 23  EFTF - South Stuart Corridor                       NaN           NaN
# 24  EFTF - South Stuart Corridor                       NaN           NaN
# 25  EFTF - South Stuart Corridor                       NaN           NaN
# 26  EFTF - South Stuart Corridor                       NaN           NaN
# 27  EFTF - South Stuart Corridor                       NaN           NaN
# 28  EFTF - South Stuart Corridor                       NaN           NaN
# 29  EFTF - South Stuart Corridor                       NaN           NaN
# 30  EFTF - South Stuart Corridor                       NaN           NaN
# 31  EFTF - South Stuart Corridor                       NaN           NaN
# 32  EFTF - South Stuart Corridor                       NaN           NaN
# 33  EFTF - South Stuart Corridor                       NaN           NaN
# 34  EFTF - South Stuart Corridor                       NaN           NaN
# 35  EFTF - South Stuart Corridor                       NaN           NaN
# 36  EFTF - South Stuart Corridor                       NaN           NaN
# 37  EFTF - South Stuart Corridor                       NaN           NaN
# 38  EFTF - South Stuart Corridor                       NaN           NaN
# 39  EFTF - South Stuart Corridor                       NaN           NaN
# 40  EFTF - South Stuart Corridor                       NaN           NaN
# 41  EFTF - South Stuart Corridor                       NaN           NaN
# 42  EFTF - South Stuart Corridor                       NaN           NaN
# 43  EFTF - South Stuart Corridor                       NaN           NaN
# 44  EFTF - South Stuart Corridor                       NaN           NaN
# 45  EFTF - South Stuart Corridor                       NaN           NaN
# 46  EFTF - South Stuart Corridor                       NaN           NaN
# 47  EFTF - South Stuart Corridor                       NaN           NaN
# 48  EFTF - South Stuart Corridor                       NaN           NaN
# 49  EFTF - South Stuart Corridor                       NaN           NaN
#
#                                     COMMENTS IGSN SPECIMEN MASS MASS UOM  \
# 0                                 Black soil  NaN           NaN      NaN
# 1                                   Red clay  NaN           NaN      NaN
# 2                                 Brown silt  NaN           NaN      NaN
# 3                         Brown silt/gravels  NaN           NaN      NaN
# 4                                 Brown sand  NaN           NaN      NaN
# 5                                  Sandstone  NaN           NaN      NaN
# 6                                 Black soil  NaN           NaN      NaN
# 7                                   Red clay  NaN           NaN      NaN
# 8                        Red clay/brown silt  NaN           NaN      NaN
# 9       Brown clay with siltstone and gravel  NaN           NaN      NaN
# 10                           Brown siltstone  NaN           NaN      NaN
# 11                    Brown, white sandstone  NaN           NaN      NaN
# 12       Brown, white sandstone with gravels  NaN           NaN      NaN
# 13                                Black soil  NaN           NaN      NaN
# 14                                  Red clay  NaN           NaN      NaN
# 15               Sandy gravels and some clay  NaN           NaN      NaN
# 16                                Black soil  NaN           NaN      NaN
# 17                                  Red clay  NaN           NaN      NaN
# 18                           Sand and gravel  NaN           NaN      NaN
# 19                  Yellow-red and grey clay  NaN           NaN      NaN
# 20                           White sandstone  NaN           NaN      NaN
# 21                                Black soil  NaN           NaN      NaN
# 22                         Red clay and silt  NaN           NaN      NaN
# 23                                Brown sand  NaN           NaN      NaN
# 24                          Sand and gravels  NaN           NaN      NaN
# 25                                 Sandstone  NaN           NaN      NaN
# 26                                Black soil  NaN           NaN      NaN
# 27                         Red clay and silt  NaN           NaN      NaN
# 28   Sand and gravels, plus some yellow clay  NaN           NaN      NaN
# 29                                  Red clay  NaN           NaN      NaN
# 30                           Sand and gravel  NaN           NaN      NaN
# 31                                Black soil  NaN           NaN      NaN
# 32                                  Red clay  NaN           NaN      NaN
# 33                    Brown sand and gravels  NaN           NaN      NaN
# 34                            Dark grey clay  NaN           NaN      NaN
# 35                           Dark brown clay  NaN           NaN      NaN
# 36                    Light brown sandy clay  NaN           NaN      NaN
# 37              Mottled red brown sandy clay  NaN           NaN      NaN
# 38          Cream, pink, and brown sandstone  NaN           NaN      NaN
# 39                        Dark grey mudstone  NaN           NaN      NaN
# 40                     Fine light brown sand  NaN           NaN      NaN
# 41                     Consolidated red sand  NaN           NaN      NaN
# 42                      Red brown sandy clay  NaN           NaN      NaN
# 43                 Light orange friable sand  NaN           NaN      NaN
# 44                     Soft orange sandstone  NaN           NaN      NaN
# 45  Soft orange brown/white banded sandstone  NaN           NaN      NaN
# 46             White grey hard/wet sandstone  NaN           NaN      NaN
# 47                                 Grey clay  NaN           NaN      NaN
# 48                            Brown/tan clay  NaN           NaN      NaN
# 49                          Broken sandstone  NaN           NaN      NaN
#
#                                                SOURCE
# 0   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 1   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 2   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 3   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 4   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 5   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 6   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 7   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 8   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 9   \\prod.lan\active\proj\futurex\StuartCorridor\...
# 10  \\prod.lan\active\proj\futurex\StuartCorridor\...
# 11  \\prod.lan\active\proj\futurex\StuartCorridor\...
# 12  \\prod.lan\active\proj\futurex\StuartCorridor\...
# 13  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 14  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 15  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 16  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 17  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 18  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 19  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 20  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 21  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 22  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 23  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 24  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 25  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 26  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 27  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 28  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 29  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 30  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 31  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 32  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 33  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 34  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 35  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 36  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 37  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 38  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 39  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 40  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 41  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 42  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 43  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 44  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 45  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 46  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 47  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 48  T:\proj\futurex\StuartCorridor\Working\Reuben\...
# 49  T:\proj\futurex\StuartCorridor\Working\Reuben\...
#
# [50 rows x 29 columns]

# %%
df_dict['EARTH MATERIALS']
# Out:
#         COLLECTION NAME SAMPLENO              SAMPLE ID ACCESS CODE  \
# 0   GA Lithological Log           RN029653.lithostrat.1           O
# 1   GA Lithological Log           RN029653.lithostrat.2           O
# 2   GA Lithological Log           RN029653.lithostrat.3           O
# 3   GA Lithological Log           RN029653.lithostrat.4           O
# 4   GA Lithological Log           RN029653.lithostrat.4           O
# 5   GA Lithological Log           RN029653.lithostrat.5           O
# 6   GA Lithological Log           RN029653.lithostrat.6           O
# 7   GA Lithological Log           RN029656.lithostrat.1           O
# 8   GA Lithological Log           RN029656.lithostrat.2           O
# 9   GA Lithological Log           RN029656.lithostrat.3           O
# 10  GA Lithological Log           RN029656.lithostrat.3           O
# 11  GA Lithological Log           RN029656.lithostrat.4           O
# 12  GA Lithological Log           RN029656.lithostrat.4           O
# 13  GA Lithological Log           RN029656.lithostrat.5           O
# 14  GA Lithological Log           RN029656.lithostrat.6           O
# 15  GA Lithological Log           RN029660.lithostrat.1           O
# 16  GA Lithological Log           RN029660.lithostrat.2           O
# 17  GA Lithological Log           RN029660.lithostrat.3           O
# 18  GA Lithological Log           RN029660.lithostrat.3           O
# 19  GA Lithological Log           RN029662.lithostrat.1           O
# 20  GA Lithological Log           RN029662.lithostrat.2           O
# 21  GA Lithological Log           RN029662.lithostrat.3           O
# 22  GA Lithological Log           RN029662.lithostrat.3           O
# 23  GA Lithological Log           RN029662.lithostrat.4           O
# 24  GA Lithological Log           RN029662.lithostrat.5           O
# 25  GA Lithological Log           RN029663.lithostrat.1           O
# 26  GA Lithological Log           RN029663.lithostrat.2           O
# 27  GA Lithological Log           RN029663.lithostrat.2           O
# 28  GA Lithological Log           RN029663.lithostrat.3           O
# 29  GA Lithological Log           RN029663.lithostrat.4           O
# 30  GA Lithological Log           RN029663.lithostrat.4           O
# 31  GA Lithological Log           RN029663.lithostrat.5           O
# 32  GA Lithological Log           RN029665.lithostrat.1           O
# 33  GA Lithological Log           RN029665.lithostrat.2           O
# 34  GA Lithological Log           RN029665.lithostrat.2           O
# 35  GA Lithological Log           RN029665.lithostrat.3           O
# 36  GA Lithological Log           RN029665.lithostrat.3           O
# 37  GA Lithological Log           RN029665.lithostrat.4           O
# 38  GA Lithological Log           RN029665.lithostrat.5           O
# 39  GA Lithological Log           RN029665.lithostrat.5           O
# 40  GA Lithological Log           RN029666.lithostrat.1           O
# 41  GA Lithological Log           RN029666.lithostrat.2           O
# 42  GA Lithological Log           RN029666.lithostrat.3           O
# 43  GA Lithological Log           RN029666.lithostrat.3           O
# 44  GA Lithological Log           RN030826.lithostrat.1           O
# 45  GA Lithological Log           RN030826.lithostrat.2           O
# 46  GA Lithological Log           RN030826.lithostrat.3           O
# 47  GA Lithological Log           RN030826.lithostrat.4           O
# 48  GA Lithological Log           RN030826.lithostrat.5           O
# 49  GA Lithological Log           RN030826.lithostrat.6           O
# 50  GA Lithological Log           RN034821.lithostrat.1           O
# 51  GA Lithological Log           RN034821.lithostrat.2           O
# 52  GA Lithological Log           RN034821.lithostrat.3           O
# 53  GA Lithological Log           RN034821.lithostrat.4           O
# 54  GA Lithological Log           RN034821.lithostrat.5           O
# 55  GA Lithological Log           RN034821.lithostrat.6           O
# 56  GA Lithological Log           RN034821.lithostrat.7           O
# 57  GA Lithological Log           RN038543.lithostrat.1           O
# 58  GA Lithological Log           RN038543.lithostrat.2           O
# 59  GA Lithological Log           RN038543.lithostrat.3           O
#
#     CONFIDENTIAL UNTIL DATE QA STATUS ACTIVITY CODE Unnamed: 7  \
# 0                       NaN         U             A
# 1                       NaN         U             A
# 2                       NaN         U             A
# 3                       NaN         U             A
# 4                       NaN         U             A
# 5                       NaN         U             A
# 6                       NaN         U             A
# 7                       NaN         U             A
# 8                       NaN         U             A
# 9                       NaN         U             A
# 10                      NaN         U             A
# 11                      NaN         U             A
# 12                      NaN         U             A
# 13                      NaN         U             A
# 14                      NaN         U             A
# 15                      NaN         U             A
# 16                      NaN         U             A
# 17                      NaN         U             A
# 18                      NaN         U             A
# 19                      NaN         U             A
# 20                      NaN         U             A
# 21                      NaN         U             A
# 22                      NaN         U             A
# 23                      NaN         U             A
# 24                      NaN         U             A
# 25                      NaN         U             A
# 26                      NaN         U             A
# 27                      NaN         U             A
# 28                      NaN         U             A
# 29                      NaN         U             A
# 30                      NaN         U             A
# 31                      NaN         U             A
# 32                      NaN         U             A
# 33                      NaN         U             A
# 34                      NaN         U             A
# 35                      NaN         U             A
# 36                      NaN         U             A
# 37                      NaN         U             A
# 38                      NaN         U             A
# 39                      NaN         U             A
# 40                      NaN         U             A
# 41                      NaN         U             A
# 42                      NaN         U             A
# 43                      NaN         U             A
# 44                      NaN         U             A
# 45                      NaN         U             A
# 46                      NaN         U             A
# 47                      NaN         U             A
# 48                      NaN         U             A
# 49                      NaN         U             A
# 50                      NaN         U             A
# 51                      NaN         U             A
# 52                      NaN         U             A
# 53                      NaN         U             A
# 54                      NaN         U             A
# 55                      NaN         U             A
# 56                      NaN         U             A
# 57                      NaN         U             A
# 58                      NaN         U             A
# 59                      NaN         U             A
#
#    LITHOLOGY GROUP LITHOLOGY NAME QUALIFIER 1 QUALIFIER 2 QUALIFIER 3  \
# 0         regolith           soil
# 1      sedimentary           clay
# 2      sedimentary           silt
# 3      sedimentary         gravel
# 4      sedimentary           silt
# 5      sedimentary           sand
# 6      sedimentary      sandstone
# 7         regolith           soil
# 8      sedimentary           clay
# 9      sedimentary           silt
# 10     sedimentary           clay
# 11     sedimentary      siltstone
# 12     sedimentary           clay
# 13     sedimentary      siltstone
# 14     sedimentary      sandstone
# 15        regolith           soil
# 16     sedimentary           clay
# 17     sedimentary           clay
# 18     sedimentary   sandy gravel
# 19        regolith           soil
# 20     sedimentary           clay
# 21     sedimentary         gravel
# 22     sedimentary           sand
# 23     sedimentary           clay
# 24     sedimentary      sandstone
# 25        regolith           soil
# 26     sedimentary           silt
# 27     sedimentary           clay
# 28     sedimentary           sand
# 29     sedimentary         gravel
# 30     sedimentary           sand
# 31     sedimentary      sandstone
# 32        regolith           soil
# 33     sedimentary           silt
# 34     sedimentary           clay
# 35     sedimentary         gravel
# 36     sedimentary           sand
# 37     sedimentary           clay
# 38     sedimentary         gravel
# 39     sedimentary           sand
# 40        regolith           soil
# 41     sedimentary           clay
# 42     sedimentary         gravel
# 43     sedimentary           sand
# 44     sedimentary           clay
# 45     sedimentary           clay
# 46     sedimentary     sandy clay
# 47     sedimentary     sandy clay
# 48     sedimentary      sandstone
# 49     sedimentary       mudstone
# 50     sedimentary           sand
# 51     sedimentary           sand
# 52     sedimentary     sandy clay
# 53     sedimentary           sand
# 54     sedimentary      sandstone
# 55     sedimentary      sandstone
# 56     sedimentary      sandstone
# 57     sedimentary           clay
# 58     sedimentary           clay
# 59     sedimentary      sandstone
#
#    MATERIAL DESCRIPTION MODE OF OCCURRENCE PROPORTION TERM  \
# 0                                      bed
# 1                                      bed
# 2                                      bed
# 3                                      bed
# 4                                      bed
# 5                                      bed
# 6                                      bed
# 7                                      bed
# 8                                      bed
# 9                                      bed
# 10                                     bed
# 11                                     bed
# 12                                     bed
# 13                                     bed
# 14                                     bed
# 15                                     bed
# 16                                     bed
# 17                                     bed
# 18                                     bed
# 19                                     bed
# 20                                     bed
# 21                                     bed
# 22                                     bed
# 23                                     bed
# 24                                     bed
# 25                                     bed
# 26                                     bed
# 27                                     bed
# 28                                     bed
# 29                                     bed
# 30                                     bed
# 31                                     bed
# 32                                     bed
# 33                                     bed
# 34                                     bed
# 35                                     bed
# 36                                     bed
# 37                                     bed
# 38                                     bed
# 39                                     bed
# 40                                     bed
# 41                                     bed
# 42                                     bed
# 43                                     bed
# 44                                     bed
# 45                                     bed
# 46                                     bed
# 47                                     bed
# 48                                     bed
# 49                                     bed
# 50                                     bed
# 51                                     bed
# 52                                     bed
# 53                                     bed
# 54                                     bed
# 55                                     bed
# 56                                     bed
# 57                                     bed
# 58                                     bed
# 59                                     bed
#
#     LOWER PROPORTION PERCENT  UPPER PROPORTION PERCENT  CONFIDENCE
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
# 10                       NaN                        NaN
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 13                       NaN                        NaN
# 14                       NaN                        NaN
# 15                       NaN                        NaN
# 16                       NaN                        NaN
# 17                       NaN                        NaN
# 18                       NaN                        NaN
# 19                       NaN                        NaN
# 20                       NaN                        NaN
# 21                       NaN                        NaN
# 22                       NaN                        NaN
# 23                       NaN                        NaN
# 24                       NaN                        NaN
# 25                       NaN                        NaN
# 26                       NaN                        NaN
# 27                       NaN                        NaN
# 28                       NaN                        NaN
# 29                       NaN                        NaN
# 30                       NaN                        NaN
# 31                       NaN                        NaN
# 32                       NaN                        NaN
# 33                       NaN                        NaN
# 34                       NaN                        NaN
# 35                       NaN                        NaN
# 36                       NaN                        NaN
# 37                       NaN                        NaN
# 38                       NaN                        NaN
# 39                       NaN                        NaN
# 40                       NaN                        NaN
# 41                       NaN                        NaN
# 42                       NaN                        NaN
# 43                       NaN                        NaN
# 44                       NaN                        NaN
# 45                       NaN                        NaN
# 46                       NaN                        NaN
# 47                       NaN                        NaN
# 48                       NaN                        NaN
# 49                       NaN                        NaN
# 50                       NaN                        NaN
# 51                       NaN                        NaN
# 52                       NaN                        NaN
# 53                       NaN                        NaN
# 54                       NaN                        NaN
# 55                       NaN                        NaN
# 56                       NaN                        NaN
# 57                       NaN                        NaN
# 58                       NaN                        NaN
# 59                       NaN                        NaN

# %%
df_dict['STRATIGRAPHY']#[df_dict['STRATIGRAPHY'].columns[15:]].head()
# Out:
# Empty DataFrame
# Columns: [COLLECTION NAME, SAMPLENO, SAMPLE ID, ACCESS CODE, CONFIDENTIAL UNTIL DATE, QA STATUS, ACTIVITY CODE, Unnamed: 7, FORMAL UNIT NAME, INFORMAL UNIT NAME, GA PREFERRED, INFORMAL GROUPING, GEOLOGICAL PROVINCE, MIN. NUMERIC AGE, MIN. AGE NAME, MAX. NUMERIC AGE, MAX. AGE NAME, AGE METHOD, TOP CONTACT TYPE, TOP CONTACT CHARACTER, TOP CONTACT NAME, BASE CONTACT TYPE, BASE CONTACT CHARACTER, BASE CONTACT NAME, REMARKS, CONFIDENCE]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_dict['EXTRA PROPERTIES'].head()
# Out:
#                 SAMPLEID SAMPLENO DATANO        PROPERTY TEXT VALUE  \
# 0  RN030826.lithostrat.4                  colour pattern    mottled
#
#   NUMERICAL VALUE UNIT OF MEASURE PROPORTION TERM CONFIDENCE COMMENT  \
# 0
#
#   ACCESS CODE  CONFIDENTIAL UNTIL QA STATUS ACTIVITY CODE  ANO
# 0           O                 NaN         U             A  218

# %%
template_path

# save out to new workbook
s = 'Saving output to ' + output_path + '...'
print(s, end = '', flush = True)
writer = pd.ExcelWriter(output_path)
for df_name, df in df_dict.items():
    df.to_excel(writer, df_name, index = False)
writer.save()
print('Done')
